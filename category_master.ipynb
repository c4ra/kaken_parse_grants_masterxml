# %% [markdown]
# # KAKENの研究種目マスタをローカルのMariaDBに保存するプログラム

# %% [markdown]
# ### 事前準備
# - KAKENマスタデータは、git のリポジトリで管理されており、最新のデータを利用可能。
# - https://bitbucket.org/niijp/grants_masterxml_kaken/ からリポジトリを pull して、ローカルの ./grants_masterxml_kaken フォルダに同期しておく。
# - ローカルで MariaDB を動かしておく。
# - MariaDB のユーザ名、パスワード、データベース名は、config.ipynbを使って ./config.ini として保存しておく。

# %% [markdown]
# ### ここから本編
# bitbucketから読み込んだマスタのXMLファイルをelementTreeに変換

# %%
# encoding: utf-8
from lxml import etree
import pandas as pd

# %%
tree = etree.parse('grants_masterxml_kaken/category_master_kakenhi.xml')

categorylist = []
for category_table in tree.iterfind("category_table"):
    for category in category_table.iterfind("category"):
        name = category.find("name[@lang='ja']").text
        niicode = category.find("code[@type='nii']").text

        row = [
            niicode,
            name,
        ]
        categorylist.append(row)            

df = pd.DataFrame(categorylist)
df.columns = ['category_niicode', 'category_name']
df
# Out:
#     category_niicode                 category_name
# 0                  1                          機関研究
# 1                  2                          各個研究
# 2                  3                          特定研究
# 3                  4                          総合研究
# 4                  5                          試験研究
# 5                  6                        海外学術調査
# 6                  7                       研究成果刊行費
# 7                  8                          奨励研究
# 8                  1                          機関研究
# 9                  2                          各個研究
# 10                 3                          特定研究
# 11                 4                          総合研究
# 12                 5                          試験研究
# 13                 6                        海外学術調査
# 14                 7                       研究成果刊行費
# 15                 8                          奨励研究
# 16                 9                        がん特別研究
# 17                 3                          特定研究
# 18                 5                          試験研究
# 19                 6                        海外学術調査
# 20                 7                       研究成果刊行費
# 21                 9                        がん特別研究
# 22                10                       総合研究(A)
# 23                11                       総合研究(B)
# 24                12                       一般研究(A)
# 25                13                       一般研究(B)
# 26                14                       一般研究(C)
# 27                15                       一般研究(D)
# 28                16                          一般研究
# 29                17                       奨励研究(A)
# ..               ...                           ...
# 569               64                       若手研究(A)
# 570               65                       若手研究(B)
# 571               68                       基盤研究(A)
# 572               69                       基盤研究(B)
# 573               72                       基盤研究(C)
# 574               73              新学術領域研究(研究領域提案型)
# 575               75                       挑戦的萌芽研究
# 576               76                    研究活動スタート支援
# 577               77          国際共同研究加速基金(国際共同研究強化)
# 578               79            国際共同研究加速基金(帰国発展研究)
# 579              247  新学術領域研究（研究領域提案型）『学術研究支援基盤形成』
# 580              249                     挑戦的研究(開拓)
# 581              250                     挑戦的研究(萌芽)
# 582               28                        特別推進研究
# 583               42                      特別研究員奨励費
# 584               55                       特別研究促進費
# 585               60                       基盤研究(S)
# 586               63                          奨励研究
# 587               68                       基盤研究(A)
# 588               69                       基盤研究(B)
# 589               72                       基盤研究(C)
# 590               73              新学術領域研究(研究領域提案型)
# 591               75                       挑戦的萌芽研究
# 592               76                    研究活動スタート支援
# 593               77          国際共同研究加速基金(国際共同研究強化)
# 594               79            国際共同研究加速基金(帰国発展研究)
# 595              247  新学術領域研究（研究領域提案型）『学術研究支援基盤形成』
# 596              249                     挑戦的研究(開拓)
# 597              250                     挑戦的研究(萌芽)
# 598              252                          若手研究
#
# [599 rows x 2 columns]

# %% [markdown]
# 重複のデータがあるかどうか

# %%
df.duplicated().any()
# Out:
# True

# %% [markdown]
# 重複データがあった。dropしておく。

# %%
df = df.drop_duplicates()
df.duplicated().any()
# Out:
# False

# %%
df.category_niicode.value_counts()
# Out:
# 41     1
# 57     1
# 72     1
# 51     1
# 5      1
# 26     1
# 9      1
# 20     1
# 31     1
# 66     1
# 14     1
# 73     1
# 17     1
# 76     1
# 47     1
# 44     1
# 70     1
# 34     1
# 39     1
# 18     1
# 4      1
# 32     1
# 33     1
# 54     1
# 74     1
# 16     1
# 25     1
# 65     1
# 45     1
# 62     1
#       ..
# 64     1
# 23     1
# 30     1
# 75     1
# 36     1
# 46     1
# 29     1
# 53     1
# 249    1
# 56     1
# 10     1
# 58     1
# 69     1
# 68     1
# 42     1
# 77     1
# 13     1
# 40     1
# 19     1
# 48     1
# 60     1
# 15     1
# 2      1
# 247    1
# 12     1
# 55     1
# 71     1
# 37     1
# 43     1
# 250    1
# Name: category_niicode, Length: 80, dtype: int64

# %% [markdown]
# niicodeがユニークなので、インデックスに設定する

# %%
df = df.set_index('category_niicode')
df

# %% [markdown]
# ローカルのmariaDBに関する設定ファイルを読み込み（config.iniはgitに上げていないが、事前準備で作られているはず）

# %%
import configparser

config = configparser.ConfigParser()
config.read('config.ini')
username = config['mariadb']['username']
password = config['mariadb']['password']
database = config['mariadb']['database']
url = 'mysql+pymysql://' + username + ':' + password + '@localhost:3306/' + database + '?charset=utf8'

# %% [markdown]
# データベースにテーブル構造とデータの中身を書き込む

# %%
from sqlalchemy import create_engine
from sqlalchemy.types import String, Integer

engine = create_engine(url, echo=True)

df.to_sql('kaken_master_category', engine, if_exists='replace',
          dtype={
              'category_niicode': Integer,
              'category_name': String(256),
                })
# Out:
# 2018-05-09 12:00:52,742 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2018-05-09 12:00:52,743 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,745 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2018-05-09 12:00:52,746 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,748 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8' and `Collation` = 'utf8_bin'
# 2018-05-09 12:00:52,749 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,751 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2018-05-09 12:00:52,752 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,754 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# 2018-05-09 12:00:52,755 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,756 INFO sqlalchemy.engine.base.Engine SELECT CAST('test collated returns' AS CHAR CHARACTER SET utf8) COLLATE utf8_bin AS anon_1
# 2018-05-09 12:00:52,757 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,758 INFO sqlalchemy.engine.base.Engine DESCRIBE `kaken_master_category`
# 2018-05-09 12:00:52,759 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,775 INFO sqlalchemy.engine.base.Engine DESCRIBE `kaken_master_category`
# 2018-05-09 12:00:52,776 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,791 INFO sqlalchemy.engine.base.Engine SHOW FULL TABLES FROM `data_analysis`
# 2018-05-09 12:00:52,792 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,793 INFO sqlalchemy.engine.base.Engine SHOW CREATE TABLE `kaken_master_category`
# 2018-05-09 12:00:52,794 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,798 INFO sqlalchemy.engine.base.Engine
# DROP TABLE kaken_master_category
# 2018-05-09 12:00:52,799 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,807 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-05-09 12:00:52,809 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE kaken_master_category (
# 	category_niicode INTEGER,
# 	category_name VARCHAR(256)
# )
#
#
# 2018-05-09 12:00:52,810 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,828 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-05-09 12:00:52,829 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_kaken_master_category_category_niicode ON kaken_master_category (category_niicode)
# 2018-05-09 12:00:52,830 INFO sqlalchemy.engine.base.Engine {}
# 2018-05-09 12:00:52,839 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-05-09 12:00:52,842 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2018-05-09 12:00:52,843 INFO sqlalchemy.engine.base.Engine INSERT INTO kaken_master_category (category_niicode, category_name) VALUES (%(category_niicode)s, %(category_name)s)
# 2018-05-09 12:00:52,844 INFO sqlalchemy.engine.base.Engine ({'category_niicode': '1', 'category_name': '機関研究'}, {'category_niicode': '2', 'category_name': '各個研究'}, {'category_niicode': '3', 'category_name': '特定研究'}, {'category_niicode': '4', 'category_name': '総合研究'}, {'category_niicode': '5', 'category_name': '試験研究'}, {'category_niicode': '6', 'category_name': '海外学術調査'}, {'category_niicode': '7', 'category_name': '研究成果刊行費'}, {'category_niicode': '8', 'category_name': '奨励研究'}  ... displaying 10 of 80 total bound parameter sets ...  {'category_niicode': '250', 'category_name': '挑戦的研究(萌芽)'}, {'category_niicode': '252', 'category_name': '若手研究'})
# 2018-05-09 12:00:52,848 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# ### おしまい
# データがコミットされていれば終了。HeidiSQLなどで、上記ドロップ済みデータフレームの件数が登録されているか確認する。
